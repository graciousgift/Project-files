# %% [markdown]
# <a href="https://colab.research.google.com/github/graciousgift/Assignment-file/blob/main/GiftMaren_Project_Assignment_wk7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Gift Lawrence Maren**

# %%
# %pip install nb_black
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.6 MB 6.2 MB/s
# ...
#      |████████████████████████████████| 96 kB 5.6 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 46.4 MB/s
# ...
#   Created wheel for nb-black: filename=nb_black-1.0.7-py3-none-any.whl size=5298 sha256=4040509fb917a9a0a70dedccfd70f07e2fefe0d84c862e734a3155810c72a452
#   Stored in directory: /root/.cache/pip/wheels/a6/5e/1e/a15614d6ea220d070043db3b650d73a8b4938aefd520496c11
# Successfully built nb-black
# ...
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires click<8.0,>=5.1, but you have click 8.1.3 which is incompatible.
# ...

# %%
# Standard imports
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import sqlite3
import seaborn as sns

sns.set()

# Built-in library
import itertools
import re
import json
import typing as tp

# pandas settings
pd.options.display.max_rows = 1_000
pd.options.display.max_columns = 1_000
pd.options.display.max_colwidth = 600

# Black code formatter (Optional)
# %load_ext lab_black
# auto reload imports
# %load_ext autoreload
# %autoreload 2

# %%
# connect to database
conn = sqlite3.connect("attr_data.db")
print("connected successfully") #check if database connected successfully
# Out:
# connected successfully

# %%
#create cursor object
cursor = conn.cursor()
#check if cursor is created
print("cursor created")
# Out:
# cursor created

# %%
#using pandas to display query in a dataframe
df = pd.read_sql_query("SELECT * FROM 'attrition_records';", conn)
df.head()
# Out:
#    id  Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   1   41       Yes      Travel_Rarely       1102                   Sales
# 1   2   49        No  Travel_Frequently        279  Research & Development
# 2   3   37       Yes      Travel_Rarely       1373  Research & Development
# 3   4   33        No  Travel_Frequently       1392  Research & Development
# 4   5   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %% [markdown]
# 1. Find the 3 factors behind Employee Attrition

# %%
plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='Age',
    y='Attrition',
    palette='Accent'
      )
plt.show()
plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='DailyRate',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='Education',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='HourlyRate',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='JobInvolvement',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='JobLevel',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='JobSatisfaction',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='MonthlyRate',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='MonthlyIncome',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='NumCompaniesWorked',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='PercentSalaryHike',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='PerformanceRating',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='RelationshipSatisfaction',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='StandardHours',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='StockOptionLevel',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='TotalWorkingYears',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='TrainingTimesLastYear',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='WorkLifeBalance',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='YearsAtCompany',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='YearsInCurrentRole',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='YearsSinceLastPromotion',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='YearsWithCurrManager',
    y='Attrition',
    palette='Accent'
      )
plt.show()

plt.figure(figsize=(3,3))
sns.boxplot(
    data= df, 
    x='PerformanceRating',
    y='Attrition',
    palette='Accent'
      )
plt.show()

# %%
# for categorical data
plt.figure(figsize=(5,3))
sns.countplot (x='BusinessTravel', hue='Attrition', data=df)
plt.title('Business Tavel Against Attrition', size='large')
plt.xlabel('BusinessTravel', size='large', color='r')
plt.show()

plt.figure(figsize=(5,3))
sns.countplot (x='Department', hue='Attrition', data=df)
plt.title('Department Against Attrition', size='large')
plt.xlabel('Department', size='large', color='r')
plt.show()

plt.figure(figsize=(5,3))
sns.countplot (x='EducationField', hue='Attrition', data=df)
plt.title('EducationField Against Attrition', size='large')
plt.xlabel('EducationField', size='large', color='r')
plt.show()

plt.figure(figsize=(3,3))
sns.countplot (x='Gender', hue='Attrition', data=df)
plt.title('Gender Against Attrition', size='large')
plt.xlabel('Gender', size='large', color='r')
plt.show()

plt.figure(figsize=(5,5))
sns.countplot (x='JobRole', hue='Attrition', data=df)
plt.title('JobRole Against Attrition', size='large')
plt.xlabel('JobRole', size='large', color='r')
plt.show()

plt.figure(figsize=(3,3))
sns.countplot (x='MaritalStatus', hue='Attrition', data=df)
plt.title('MaritalStatus Against Attrition', size='large')
plt.xlabel('MaritalStatus', size='large', color='r')
plt.show()

plt.figure(figsize=(3,3))
sns.countplot (x='OverTime', hue='Attrition', data=df)
plt.title('OverTime Against Attrition', size='large')
plt.xlabel('OverTime', size='large', color='r')
plt.show()

# %% [markdown]
# There are other factors that can affect Attrition, but the three major factors behind employee attrition are
# 1. Number of Companies Worked
# 2. Business Travel
# 3. Department

# %%
# Split into numerical and categorical data
numerical_vars = [var for var in df.columns if df[var].dtype !='0']
categorical_vars = [var for var in df.columns if df[var].dtype =='0']
numerical_vars, categorical_vars
# Out:
# (['id',
#   'Age',
#   'Attrition',
#   'BusinessTravel',
#   'DailyRate',
#   'Department',
#   'DistanceFromHome',
#   'Education',
#   'EducationField',
#   'EmployeeCount',
#   'EmployeeNumber',
#   'EnvironmentSatisfaction',
#   'Gender',
#   'HourlyRate',
#   'JobInvolvement',
#   'JobLevel',
#   'JobRole',
#   'JobSatisfaction',
#   'MaritalStatus',
#   'MonthlyIncome',
#   'MonthlyRate',
#   'NumCompaniesWorked',
#   'Over18',
#   'OverTime',
#   'PercentSalaryHike',
#   'PerformanceRating',
#   'RelationshipSatisfaction',
#   'StandardHours',
#   'StockOptionLevel',
#   'TotalWorkingYears',
#   'TrainingTimesLastYear',
#   'WorkLifeBalance',
#   'YearsAtCompany',
#   'YearsInCurrentRole',
#   'YearsSinceLastPromotion',
#   'YearsWithCurrManager'],
#  [])

# %%
temp = df["Attrition"].value_counts()
# Reset index
temp = (
    pd.DataFrame(temp)
    .rename(columns={"index": "Attrition", "Attrition": "Count"})
)
temp
# Out:
#      Count
# No    1233
# Yes    237

# %%
# Using Boxplot to determine the relationship between Education and Monthly Income
plt.figure(figsize=(10,10))
sns.boxplot(
    data= df, 
    x='Education',
    y='MonthlyIncome',
    palette='Accent'
      )
plt.title("Relationship between Education and Monthly Income", fontsize=20, fontweight="bold")
plt.show()

# %% [markdown]
# The Relationship Between Education and Monthlyincome is as floows:
# 1. The PHD Doctor's (5) income is higher than that of the other education categories(1,2,3,4).
# 2. Secondly all the education level have a minimum income of below 2500.

# %%
# Effect of Age on Attrition

plt.figure(figsize=(10,5))
sns.boxplot(
    data= df, 
    x='Age',
    y='Attrition',
    palette='Accent'
      )
plt.title("Effect of Age on Attrition", fontsize=20, fontweight="bold")
plt.show()

# %% [markdown]
# 3.Age has no Significant effect on Attrition

# %%
plt.figure(figsize=(10,5))
sns.boxplot(
    data= df, 
    x='MonthlyIncome',
    y='Attrition',
    palette='Accent'
);
plt.show()

# %% [markdown]
# 4. Income is not a main factor in Employee Attrition

# %%
sns.violinplot(x=df['WorkLifeBalance'], y=df['Attrition'], orient='horizontal')
plt.show()

# %% [markdown]
# 5. Work Life Balance  does not have much impact on attrition but looks Better on Attrition with a median of 3.0 out of 4.0
